# %% [markdown]
# # Soru1 :
# miuul_gezinomi.xlsx dosyasını okutunuz ve veri seti ile ilgili genel bilgileri gösteriniz.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel("C:/Users/HP-PC/Desktop/miuul_gezinomi.xlsx")
data.head()
# Out:
#    SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 0  415122 2022-12-03  2022-12-03   79.304029    Herşey Dahil      Antalya
# 1  415103 2022-12-03  2022-12-03   45.970696  Yarım Pansiyon      Antalya
# 2  404034 2022-09-12  2022-09-13   77.838828    Herşey Dahil      Antalya
# 3  415094 2022-12-03  2022-12-10  222.710623  Yarım Pansiyon        İzmir
# 4  414951 2022-12-01  2022-12-03  140.476190  Yarım Pansiyon        İzmir
#
#      CInDay  SaleCheckInDayDiff Seasons
# 0  Saturday                   0     Low
# 1  Saturday                   0     Low
# 2   Tuesday                   1    High
# 3  Saturday                   7     Low
# 4  Saturday                   2     Low

# %% [markdown]
# Genel Bilgiler:

# %%
data.tail()
# Out:
#        SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 59159   51817 2016-01-05  2016-10-10   54.304636    Herşey Dahil      Antalya
# 59160   51816 2016-01-05  2016-10-10   54.304636    Herşey Dahil      Antalya
# 59161   51814 2016-01-05  2016-01-06   40.562914    Herşey Dahil        Diğer
# 59162   51736 2016-01-04  2016-01-05   69.847682  Yarım Pansiyon        Diğer
# 59163   51731 2016-01-04  2016-08-22  158.940397    Herşey Dahil      Antalya
#
#           CInDay  SaleCheckInDayDiff Seasons
# 59159     Monday                 279     Low
# 59160     Monday                 279     Low
# 59161  Wednesday                   1     Low
# 59162    Tuesday                   1     Low
# 59163     Monday                 231    High

# %%
data.shape
# Out:
# (59164, 9)

# %%
data.dtypes
# Out:
# SaleId                         int64
# SaleDate              datetime64[ns]
# CheckInDate           datetime64[ns]
# Price                        float64
# ConceptName                   object
# SaleCityName                  object
# CInDay                        object
# SaleCheckInDayDiff             int64
# Seasons                       object
# dtype: object

# %%
data.columns
# Out:
# Index(['SaleId', 'SaleDate', 'CheckInDate', 'Price', 'ConceptName',
#        'SaleCityName', 'CInDay', 'SaleCheckInDayDiff', 'Seasons'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=59164, step=1)

# %%
data["Price"].describe()
# Out:
# count    59151.000000
# mean        61.345057
# std         51.384617
# min          0.000000
# 25%         35.343035
# 50%         54.261294
# 75%         77.962578
# max       4880.471380
# Name: Price, dtype: float64

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# SaleId                 0
# SaleDate               0
# CheckInDate            0
# Price                 13
# ConceptName            0
# SaleCityName           0
# CInDay                 0
# SaleCheckInDayDiff     0
# Seasons                0
# dtype: int64

# %%
data["ConceptName"].value_counts()
# Out:
# Herşey Dahil      53186
# Yarım Pansiyon     3559
# Oda + Kahvaltı     2419
# Name: ConceptName, dtype: int64

# %%
data.head()
# Out:
#    SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 0  415122 2022-12-03  2022-12-03   79.304029    Herşey Dahil      Antalya
# 1  415103 2022-12-03  2022-12-03   45.970696  Yarım Pansiyon      Antalya
# 2  404034 2022-09-12  2022-09-13   77.838828    Herşey Dahil      Antalya
# 3  415094 2022-12-03  2022-12-10  222.710623  Yarım Pansiyon        İzmir
# 4  414951 2022-12-01  2022-12-03  140.476190  Yarım Pansiyon        İzmir
#
#      CInDay  SaleCheckInDayDiff Seasons
# 0  Saturday                   0     Low
# 1  Saturday                   0     Low
# 2   Tuesday                   1    High
# 3  Saturday                   7     Low
# 4  Saturday                   2     Low

# %%
data.loc[0:4, 'SaleDate':'Price']
# Out:
#     SaleDate CheckInDate       Price
# 0 2022-12-03  2022-12-03   79.304029
# 1 2022-12-03  2022-12-03   45.970696
# 2 2022-09-12  2022-09-13   77.838828
# 3 2022-12-03  2022-12-10  222.710623
# 4 2022-12-01  2022-12-03  140.476190

# %%
data.iloc[2:4, 1:3]
# Out:
#     SaleDate CheckInDate
# 2 2022-09-12  2022-09-13
# 3 2022-12-03  2022-12-10

# %%
data.head()
# Out:
#    SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 0  415122 2022-12-03  2022-12-03   79.304029    Herşey Dahil      Antalya
# 1  415103 2022-12-03  2022-12-03   45.970696  Yarım Pansiyon      Antalya
# 2  404034 2022-09-12  2022-09-13   77.838828    Herşey Dahil      Antalya
# 3  415094 2022-12-03  2022-12-10  222.710623  Yarım Pansiyon        İzmir
# 4  414951 2022-12-01  2022-12-03  140.476190  Yarım Pansiyon        İzmir
#
#      CInDay  SaleCheckInDayDiff Seasons
# 0  Saturday                   0     Low
# 1  Saturday                   0     Low
# 2   Tuesday                   1    High
# 3  Saturday                   7     Low
# 4  Saturday                   2     Low

# %%
"Price" in data
# Out:
# True

# %%
type(data["Price"].head())
# Out:
# pandas.core.series.Series

# %%
data[data["Price"]>45.970696]["Price"].count()
# Out:
# 35826

# %% [markdown]
# # Soru 2:
# Kaç unique şehir vardır? Frekansları nedir?
#
# NOT:
# Aradaki fark şudur: unique() işlevi, sütunun tüm benzersiz değerlerini bir dizi biçiminde döndürür. nunique() işlevi, tüm benzersiz değerlerin sayısını döndürür.

# %%
data.head()
# Out:
#    SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 0  415122 2022-12-03  2022-12-03   79.304029    Herşey Dahil      Antalya
# 1  415103 2022-12-03  2022-12-03   45.970696  Yarım Pansiyon      Antalya
# 2  404034 2022-09-12  2022-09-13   77.838828    Herşey Dahil      Antalya
# 3  415094 2022-12-03  2022-12-10  222.710623  Yarım Pansiyon        İzmir
# 4  414951 2022-12-01  2022-12-03  140.476190  Yarım Pansiyon        İzmir
#
#      CInDay  SaleCheckInDayDiff Seasons
# 0  Saturday                   0     Low
# 1  Saturday                   0     Low
# 2   Tuesday                   1    High
# 3  Saturday                   7     Low
# 4  Saturday                   2     Low

# %%
data["SaleCityName"].nunique()
# Out:
# 6

# %%
#Frekansları:
print(data["SaleCityName"].value_counts())
# Out:
# Antalya    31649
# Muğla      10662
# Aydın      10646
# Diğer       3245
# İzmir       2507
# Girne        455
# Name: SaleCityName, dtype: int64

# %% [markdown]
# # Soru 3:
# Kaç unique Concept vardır?

# %%
data["ConceptName"].nunique()
# Out:
# 3

# %% [markdown]
# # Soru4:
# Hangi Concept’den kaçar tane satış gerçekleşmiş?

# %%
data["ConceptName"].value_counts()
# Out:
# Herşey Dahil      53186
# Yarım Pansiyon     3559
# Oda + Kahvaltı     2419
# Name: ConceptName, dtype: int64

# %% [markdown]
# # Soru5:
# Şehirlere göre satışlardan toplam ne kadar kazanılmış?

# %%
city, price

# %%
#Daha düzenli çıktı veriyor.
data.groupby("SaleCityName").agg({"Price": "sum"})

#Benim yaptığım.
#data.groupby(["SaleCityName"]).sum()['Price']

#df.groupby(by=['Country']).count()['Student']
# Out:
#                      Price
# SaleCityName
# Antalya       2.041911e+06
# Aydın         5.732960e+05
# Diğer         1.545723e+05
# Girne         2.706503e+04
# Muğla         6.658422e+05
# İzmir         1.659348e+05

# %% [markdown]
# # Soru6:
#  Concept türlerine göre ne kadar kazanılmış?

# %%
#Daha düzenli çıktı veriyor.
data.groupby("ConceptName").agg({"Price": "sum"})

#Benim yaptığım.
#data.groupby(["ConceptName"]).sum()['Price']
# Out:
#                        Price
# ConceptName
# Herşey Dahil    3.332911e+06
# Oda + Kahvaltı  1.213084e+05
# Yarım Pansiyon  1.744024e+05

# %% [markdown]
# # Soru7:
# Şehirlere göre PRICE ortalamaları nedir?

# %%
#Daha düzenli çıktı veriyor.
data.groupby(by=['SaleCityName']).agg({"Price": "mean"})

#Benim yaptığım.
#data.groupby(["SaleCityName"]).mean()['Price']
# Out:
#                   Price
# SaleCityName
# Antalya       64.521474
# Aydın         53.855896
# Diğer         47.707497
# Girne         59.483579
# Muğla         62.461746
# İzmir         66.267905

# %% [markdown]
# # Soru 8:
# Conceptlere göre PRICE ortalamaları nedir

# %%
#Daha düzenli çıktı veriyor.
data.groupby(by=['ConceptName']).agg({"Price": "mean"})

#Benim yaptığım.
#data.groupby(["ConceptName"]).mean()['Price']
# Out:
#                     Price
# ConceptName
# Herşey Dahil    62.672260
# Oda + Kahvaltı  50.252010
# Yarım Pansiyon  49.030742

# %% [markdown]
# # Soru 9:
# Şehir-Concept kırılımındaPRICE ortalamalarınedir?

# %%
#Daha düzenli çıktı veriyor.
data.groupby(by=["SaleCityName", 'ConceptName']).agg({"Price": "mean"})

#Benim yaptığım.
#data.groupby(["SaleCityName", "ConceptName"]).agg({"Price":["mean"]})
# Out:
#                                  Price
# SaleCityName ConceptName
# Antalya      Herşey Dahil    64.519028
#              Oda + Kahvaltı  63.504816
#              Yarım Pansiyon  67.190613
# Aydın        Herşey Dahil    53.995467
#              Oda + Kahvaltı  34.458787
#              Yarım Pansiyon  30.016543
# Diğer        Herşey Dahil    84.771093
#              Oda + Kahvaltı  37.599082
#              Yarım Pansiyon  42.113440
# Girne        Herşey Dahil    97.680970
#              Oda + Kahvaltı  39.775536
#              Yarım Pansiyon  53.247838
# Muğla        Herşey Dahil    63.020053
#              Oda + Kahvaltı  59.037763
#              Yarım Pansiyon  45.120924
# İzmir        Herşey Dahil    74.701519
#              Oda + Kahvaltı  41.320342
#              Yarım Pansiyon  59.610053

# %% [markdown]
# # GÖREV-2

# %% [markdown]
# • Satis_checkin_day_diff değişkenini EB_Score adında yeni bir kategorik değişkene çeviriniz.
#
# • SaleCheckInDayDiff değişkeni müşterinin CheckIn tarihinden ne kadar önce satin alımını tamamladığını gösterir.
# • Aralıkları ikna edici şekilde oluşturunuz.
# Örneğin: ‘0_7’, ‘7_30', ‘30_90', ‘90_max’ aralıklarını kullanabilirsiniz.
# • Bu aralıklar için "Last Minuters", "Potential Planners", "Planners", "Early Bookers" isimlerini kullanabilirsiniz.
#
# NOT:
# Burada "label" ve "90>" ifadesi ekleyemedim.

# %%
bins = [-1, 7, 30, 90, data["SaleCheckInDayDiff"].max()]
labels = ["Last Minuters", "Potential Planners", "Planners", "Early Bookers"]

# %%
data["EB_Score"] = pd.cut(data["SaleCheckInDayDiff"], bins, labels=labels)
data.head(50).to_excel("miuul_gezinomi.xlsx", index=False)

# %%
data.head(50)
# Out:
#     SaleId   SaleDate CheckInDate       Price     ConceptName SaleCityName  \
# 0   415122 2022-12-03  2022-12-03   79.304029    Herşey Dahil      Antalya
# 1   415103 2022-12-03  2022-12-03   45.970696  Yarım Pansiyon      Antalya
# 2   404034 2022-09-12  2022-09-13   77.838828    Herşey Dahil      Antalya
# 3   415094 2022-12-03  2022-12-10  222.710623  Yarım Pansiyon        İzmir
# 4   414951 2022-12-01  2022-12-03  140.476190  Yarım Pansiyon        İzmir
# 5   415091 2022-12-03  2022-12-03   70.268620  Yarım Pansiyon        İzmir
# 6   415085 2022-12-03  2022-12-09   45.787546  Yarım Pansiyon      Antalya
# 7   415084 2022-12-03  2022-12-03   51.239316    Herşey Dahil      Antalya
# 8   415081 2022-12-03  2022-12-04   77.289377  Yarım Pansiyon        İzmir
# 9   415079 2022-12-03  2022-12-03   68.681319  Yarım Pansiyon        Diğer
# 10  415076 2022-12-03  2022-12-03  103.021978  Yarım Pansiyon        Diğer
# ...

# %% [markdown]
# # GÖREV-3
#
# COUNTRY, SOURCE, SEX, AGE kırılımında ortalama kazançlar nedir?
#
# Şehir-Concept-EB Score, Şehir-Concept- Sezon, Şehir-Concept-CInDay kırılımında ortalama ödenen ücret ve yapılan işlem sayısı cinsinden
# inceleyiniz ?
#
#
# Not:
# EB score yukarıda cut ile label oluşturamadığım için yapmadım. Diğer kırılımları nasıl ekleyeceğim bilmiyorum.

# %%
#Benim yaptığım:
data.groupby(["SaleCityName", "ConceptName","EB_Score"]).agg({
            "Price":["mean", "count"]})

#Hocanın yaptığı:
data.groupby(by=["SaleCityName", 'ConceptName', "EB_Score" ]).agg({"Price": ["mean", "count"]})
# Out:
#                                                     Price
#                                                      mean  count
# SaleCityName ConceptName    EB_Score
# Antalya      Herşey Dahil   Last Minuters       62.752916  14148
#                             Potential Planners  64.903700   8874
#                             Planners            67.879960   4490
#                             Early Bookers       66.494885   3281
#              Oda + Kahvaltı Last Minuters       65.353740    503
#                             Potential Planners  57.735542     75
#                             Planners            39.851330     15
#                             Early Bookers       35.002594      5
#              Yarım Pansiyon Last Minuters       70.433576    204
#                             Potential Planners  55.639242     39
#                             Planners            58.032913      9
#                             Early Bookers       35.030208      4
# ...

# %%
#Şehir-Concept- Sezon
data.groupby(["SaleCityName", "ConceptName", "Seasons"]).agg({
            "Price":["mean", "count"]})
# Out:
#                                           Price
#                                            mean  count
# SaleCityName ConceptName    Seasons
# Antalya      Herşey Dahil   High      64.920065  27126
#                             Low       61.552427   3667
#              Oda + Kahvaltı High      66.267969    303
#                             Low       60.666730    295
#              Yarım Pansiyon High      73.259029    118
#                             Low       62.001678    138
# Aydın        Herşey Dahil   High      54.946560  10103
#                             Low       33.680699    473
#              Oda + Kahvaltı High      30.387530     27
#                             Low       44.451874     11
#              Yarım Pansiyon High      32.626152     20
#                             Low       25.271799     11
# Diğer        Herşey Dahil   High      83.787273    364
#                             Low       87.310882    141
#              Oda + Kahvaltı High      34.839543    349
# ...

# %%
#Şehir-Concept-CInDay
data.groupby(["SaleCityName", "ConceptName", "CInDay"]).agg({
            "Price":["mean", "count"]})
# Out:
#                                            Price
#                                             mean count
# SaleCityName ConceptName    CInDay
# Antalya      Herşey Dahil   Friday     62.658940  4136
#                             Monday     63.259143  6831
#                             Saturday   64.415526  4741
#                             Sunday     65.849177  3818
#                             Thursday   62.892734  3898
#                             Tuesday    66.771658  3760
#                             Wednesday  67.173832  3609
#              Oda + Kahvaltı Friday     63.128165   114
#                             Monday     57.172843    66
#                             Saturday   58.012419   117
#                             Sunday     63.469286    46
#                             Thursday   64.652956    93
#                             Tuesday    65.836347    73
#                             Wednesday  72.809471    89
#              Yarım Pansiyon Friday     69.255990    38
# ...

# %% [markdown]
# # GÖREV-4
#  City-Concept-Season kırılımının çıktısını PRICE'a göre sıralayınız. Elde edilen çıktıyı "agg_df" olarak kayıt ediniz.
#
#
# NOT:
# Price ı mean na göre sıralayamadım. Direkt price ı alıp sıraladım büyükten küçüğe.

# %%
#Benim yaptığım:

agg_df = data[["SaleCityName", "ConceptName", "Seasons", "Price"]]
agg_df.sort_values("Price", ascending = False).head()
# Out:
#       SaleCityName   ConceptName Seasons        Price
# 41028        Aydın  Herşey Dahil    High  4880.471380
# 42487      Antalya  Herşey Dahil     Low  3908.701854
# 12975      Antalya  Herşey Dahil    High  2773.962149
# 38610      Antalya  Herşey Dahil    High  2735.381594
# 42484      Antalya  Herşey Dahil     Low  2574.893010

# %%
#Hocanın yaptığı: (Baya iyi)
agg_df = data.groupby(["SaleCityName", "ConceptName", "Seasons"]).agg({"Price": "mean"}).sort_values("Price", ascending=False)
agg_df.head(20)
# Out:
#                                           Price
# SaleCityName ConceptName    Seasons
# Girne        Herşey Dahil   High     103.935448
#                             Low       90.935944
# İzmir        Yarım Pansiyon High      87.657303
# Diğer        Herşey Dahil   Low       87.310882
#                             High      83.787273
# İzmir        Herşey Dahil   High      74.748363
#                             Low       74.308287
# Antalya      Yarım Pansiyon High      73.259029
#              Oda + Kahvaltı High      66.267969
#              Herşey Dahil   High      64.920065
# Muğla        Herşey Dahil   High      63.384036
# Antalya      Yarım Pansiyon Low       62.001678
#              Herşey Dahil   Low       61.552427
# Muğla        Oda + Kahvaltı High      61.264691
# Antalya      Oda + Kahvaltı Low       60.666730
# Girne        Yarım Pansiyon High      58.383668
# İzmir        Yarım Pansiyon Low       55.350626
# Aydın        Herşey Dahil   High      54.946560
# ...

# %% [markdown]
# # GÖREV-5
# Indekste yer alan isimleri değişken ismine çeviriniz.
# Üçüncü sorunun çıktısında yer alan PRICE dışındaki tüm değişkenler index isimleridir. Bu isimleri değişken isimlerine çeviriniz.
#
# NOT:
# Bu soruyu doğru yaptım mı emin değilim.

# %%
#Benim yaptığım:

data.index
data1 = pd.DataFrame(data, columns = ['SaleCityName','ConceptName','Seasons', 'Price'], index = ['Item_1','Item_2','Item_3','Item_4','Item_5'])

data1.reset_index(inplace=True)
data1
# Out:
#     index SaleCityName ConceptName Seasons  Price
# 0  Item_1          NaN         NaN     NaN    NaN
# 1  Item_2          NaN         NaN     NaN    NaN
# 2  Item_3          NaN         NaN     NaN    NaN
# 3  Item_4          NaN         NaN     NaN    NaN
# 4  Item_5          NaN         NaN     NaN    NaN

# %%
#Hocanın yaptığı:
agg_df.reset_index(inplace=True)
agg_df.head(20)
# Out:
#    SaleCityName     ConceptName Seasons       Price
# 0         Girne    Herşey Dahil    High  103.935448
# 1         Girne    Herşey Dahil     Low   90.935944
# 2         İzmir  Yarım Pansiyon    High   87.657303
# 3         Diğer    Herşey Dahil     Low   87.310882
# 4         Diğer    Herşey Dahil    High   83.787273
# 5         İzmir    Herşey Dahil    High   74.748363
# 6         İzmir    Herşey Dahil     Low   74.308287
# 7       Antalya  Yarım Pansiyon    High   73.259029
# 8       Antalya  Oda + Kahvaltı    High   66.267969
# 9       Antalya    Herşey Dahil    High   64.920065
# 10        Muğla    Herşey Dahil    High   63.384036
# 11      Antalya  Yarım Pansiyon     Low   62.001678
# 12      Antalya    Herşey Dahil     Low   61.552427
# 13        Muğla  Oda + Kahvaltı    High   61.264691
# 14      Antalya  Oda + Kahvaltı     Low   60.666730
# 15        Girne  Yarım Pansiyon    High   58.383668
# 16        İzmir  Yarım Pansiyon     Low   55.350626
# ...

# %% [markdown]
# # GÖREV-6
# Yeni seviye tabanlı müşterileri (persona) tanımlayınız.
#
# • Yeni seviye tabanlı satışları tanımlayınız ve veri setine değişken olarak ekleyiniz.
# • Yeni eklenecek değişkenin adı: sales_level_based
# • Önceki soruda elde edeceğiniz çıktıdaki gözlemleri bir araya getirerek sales_level_based değişkenini oluşturmanız gerekmektedir.

# %%
#Benim yaptığım:

data2=data[['SaleCityName','ConceptName','Seasons', 'Price']]
data2['sales_level_based'] = data2[['SaleCityName','ConceptName','Seasons']].agg(' _ '.join, axis=1)
data2.head(20)
# Out:
# C:\Users\HP-PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    SaleCityName     ConceptName Seasons       Price  \
# 0       Antalya    Herşey Dahil     Low   79.304029
# 1       Antalya  Yarım Pansiyon     Low   45.970696
# 2       Antalya    Herşey Dahil    High   77.838828
# 3         İzmir  Yarım Pansiyon     Low  222.710623
# 4         İzmir  Yarım Pansiyon     Low  140.476190
# 5         İzmir  Yarım Pansiyon     Low   70.268620
# 6       Antalya  Yarım Pansiyon     Low   45.787546
# 7       Antalya    Herşey Dahil     Low   51.239316
# 8         İzmir  Yarım Pansiyon     Low   77.289377
# 9         Diğer  Yarım Pansiyon     Low   68.681319
# ...

# %%
#Hocanın yaptığı:
agg_df['sales_level_based'] = agg_df[["SaleCityName", "ConceptName", "Seasons"]].agg(lambda x: '_'.join(x).upper(), axis=1)
agg_df.head(20)
# Out:
#    SaleCityName     ConceptName Seasons       Price  \
# 0       Antalya    Herşey Dahil     Low   79.304029
# 1       Antalya  Yarım Pansiyon     Low   45.970696
# 2       Antalya    Herşey Dahil    High   77.838828
# 3         İzmir  Yarım Pansiyon     Low  222.710623
# 4         İzmir  Yarım Pansiyon     Low  140.476190
# 5         İzmir  Yarım Pansiyon     Low   70.268620
# 6       Antalya  Yarım Pansiyon     Low   45.787546
# 7       Antalya    Herşey Dahil     Low   51.239316
# 8         İzmir  Yarım Pansiyon     Low   77.289377
# 9         Diğer  Yarım Pansiyon     Low   68.681319
# 10        Diğer  Yarım Pansiyon     Low  103.021978
# 11        Diğer  Oda + Kahvaltı     Low   39.682540
# 12        İzmir  Oda + Kahvaltı     Low   53.357753
# 13        İzmir  Yarım Pansiyon     Low   37.390527
# 14        İzmir  Yarım Pansiyon     Low   70.268620
# 15        Diğer  Yarım Pansiyon     Low  108.745421
# 16        Diğer  Yarım Pansiyon     Low  144.993895
# ...

# %% [markdown]
# # Görev 7:
#
# Yeni müşterileri (personaları) segmentlere ayırınız.
#
# • Yeni personaları PRICE’a göre 4 segmente ayırınız.
# • Segmentleri SEGMENT isimlendirmesi ile değişken olarak agg_df’e ekleyiniz.
# • Segmentleri betimleyiniz (Segmentlere göre group by yapıp price mean, max, sum’larını alınız)

# %%
#Benim yaptığım:

SEGMENT=["D", "C", "B", "A"]
data["agg_df"] = pd.qcut(data.Price, q=4, labels=["D", "C", "B", "A"])
data.groupby("agg_df").agg({"Price":["mean", "max", "sum"]})
# Out:
#              Price
#               mean          max           sum
# agg_df
# D        25.659182    35.343035  3.794480e+05
# C        44.597904    54.261294  6.596030e+05
# B        64.975656    77.962578  9.607300e+05
# A       110.153543  4880.471380  1.628840e+06

# %%
#Hocanın yaptığı:

agg_df["SEGMENT"] = pd.qcut(agg_df["Price"], 4, labels=["D", "C", "B", "A"])
agg_df.head(30)
agg_df.groupby("SEGMENT").agg({"Price": ["mean", "max", "sum"]})
# Out:
#               Price
#                mean          max           sum
# SEGMENT
# D         25.659182    35.343035  3.794480e+05
# C         44.597904    54.261294  6.596030e+05
# B         64.975656    77.962578  9.607300e+05
# A        110.153543  4880.471380  1.628840e+06

# %%
agg_df
# Out:
#       SaleCityName     ConceptName Seasons       Price  \
# 0          Antalya    Herşey Dahil     Low   79.304029
# 1          Antalya  Yarım Pansiyon     Low   45.970696
# 2          Antalya    Herşey Dahil    High   77.838828
# 3            İzmir  Yarım Pansiyon     Low  222.710623
# 4            İzmir  Yarım Pansiyon     Low  140.476190
# 5            İzmir  Yarım Pansiyon     Low   70.268620
# 6          Antalya  Yarım Pansiyon     Low   45.787546
# 7          Antalya    Herşey Dahil     Low   51.239316
# 8            İzmir  Yarım Pansiyon     Low   77.289377
# 9            Diğer  Yarım Pansiyon     Low   68.681319
# 10           Diğer  Yarım Pansiyon     Low  103.021978
# 11           Diğer  Oda + Kahvaltı     Low   39.682540
# 12           İzmir  Oda + Kahvaltı     Low   53.357753
# 13           İzmir  Yarım Pansiyon     Low   37.390527
# 14           İzmir  Yarım Pansiyon     Low   70.268620
# 15           Diğer  Yarım Pansiyon     Low  108.745421
# ...

# %% [markdown]
# # Görev 8:
# Yeni gelen müşterileri sınıflandırıp, ne kadar gelir getirebileceklerini tahmin ediniz.
#
# • Antalya’da herşey dahil ve yüksek sezonda tatil yapmak isteyen bir kişinin ortalama ne kadar gelir kazandırması beklenir?
# • Girne’de yarım pansiyon bir otele düşük sezonda giden bir tatilci hangi segmentte yer alacaktır?

# %%
#Benim yaptığım:

new_user = "Antalya_Herşey_Dahil_High"
data2[data2["sales_level_based"]==new_user]
# Out:
# Empty DataFrame
# Columns: [SaleCityName, ConceptName, Seasons, Price, sales_level_based]
# Index: []

# %%
#Hocanın yaptığı

# %%
agg_df.sort_values(by="Price").head()
# Out:
#       SaleCityName     ConceptName Seasons     Price  \
# 51094        Girne  Yarım Pansiyon    High  0.000000
# 501        Antalya    Herşey Dahil     Low  0.000000
# 51800      Antalya    Herşey Dahil     Low  0.000000
# 502        Antalya    Herşey Dahil     Low  0.000000
# 18054      Antalya    Herşey Dahil    High  0.028058
#
#                sales_level_based SEGMENT
# 51094  GIRNE_YARIM PANSIYON_HIGH       D
# 501     ANTALYA_HERŞEY DAHIL_LOW       D
# 51800   ANTALYA_HERŞEY DAHIL_LOW       D
# 502     ANTALYA_HERŞEY DAHIL_LOW       D
# 18054  ANTALYA_HERŞEY DAHIL_HIGH       D

# %%
new_user = "ANTALYA_HERŞEY DAHIL_HIGH"
agg_df[agg_df["sales_level_based"] == new_user].head(1)
# Out:
#   SaleCityName   ConceptName Seasons      Price          sales_level_based  \
# 2      Antalya  Herşey Dahil    High  77.838828  ANTALYA_HERŞEY DAHIL_HIGH
#
#   SEGMENT
# 2       B

# %%
new_user_1 = "GIRNE_YARIM PANSIYON_LOW"
agg_df[agg_df["sales_level_based"] == new_user_1].head(1)
# Out:
#     SaleCityName     ConceptName Seasons       Price  \
# 671        Girne  Yarım Pansiyon     Low  101.343101
#
#             sales_level_based SEGMENT
# 671  GIRNE_YARIM PANSIYON_LOW       A
